# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
monsters = pd.read_csv("monsterManual5e.csv")

# %%
print(type(monsters))
col_names = monsters.columns.tolist()
print(col_names)

monsters.loc[0:3]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['Unnamed: 0', 'name', 'size', 'type', 'alignment', 'armor class', 'hit points', 'speed', 'str', 'dex', 'con', 'int', 'wis', 'cha', 'proficiency bonus', 'saving throws', 'skills', 'damage vulnerabilities', 'damage resistances', 'damage immunities', 'condition immunities', 'senses', 'languages', 'challenge', 'facets', 'actions', 'legendary_actions']
#    Unnamed: 0      name    size        type    alignment  armor class  \
# 0           0   Aboleth   Large  aberration  lawful evil           17
# 1           1      Deva  Medium   celestial  lawful good           17
# 2           2  Planetar   Large   celestial  lawful good           19
# 3           3     Solar   Large   celestial  lawful good           21
#
#         hit points                    speed      str      dex  \
# 0   135(18d10+ 36)  10 ft., swim 40 ft. ft.  21 (+5)   9 (-1)
# 1    136(16d8+ 64)   30 ft., fly 90 ft. ft.  18 (+4)  18 (+4)
# ...

# %%
#cleanup types: 
if monsters['type'].iloc[167][0] == ' ': 
    monsters['type'].iloc[167] = monsters['type'].iloc[167][1:]
if monsters['type'].iloc[170][0] == ' ':
    monsters['type'].iloc[170] = monsters['type'].iloc[170][1:]

# %% [markdown]
# Now that we have had a preliminary look at the data,

# %%
#Gets counts by type: 
grouped = monsters.groupby(["type", "size"]).agg(['count'])

# %%
grouped
# Out:
#                                           Unnamed: 0  name alignment  \
#                                                count count     count
# type                           size
# aberration                     Large               4     4         4
#                                Medium              1     1         1
# beast                          Huge               10    10        10
#                                Large              30    30        30
#                                Medium             20    20        20
#                                Small               8     8         8
#                                Tiny               18    18        18
# celestial                      Large               4     4         4
#                                Medium              2     2         2
# construct                      Large               5     5         5
#                                Medium              2     2         2
# ...

# %%
monsters.loc[(monsters['size'] == 'Gargantuan') & (monsters['type'] != 'dragon'), ['name', 'size', 'type']]

# %%
saved = monsters.loc[(monsters['name'] == 'Purple Worm' ), ['type']]

# %%
saved

# %%
monsters['type'].iloc[7] == monsters['type'].iloc[170]
